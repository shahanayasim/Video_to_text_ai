# %%
# !pip install git+https://github.com/openai/whisper.git -q
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done

# %%
# !pip install gradio -q

# %%
import gradio as gr
import os
import sys
import subprocess

# %%
import whisper
model = whisper.load_model('medium')

# %%
def video2mp3(video_file, output_ext = 'mp3'):
  filename,ext = os.path.splitext(video_file)
  subprocess.call(["ffmpeg",'-y','-i',video_file,f"{filename}.{output_ext}"],
                  stdout = subprocess.DEVNULL,
                  stderr = subprocess.STDOUT)
  return f'{filename}.{output_ext}'

# %%
input_video = 'spanish.mp4'

# %%
audio_file = video2mp3(input_video)

# %%
from IPython.display import Audio
Audio(audio_file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def translate(audio):
  options = dict(beam_size=5, best_of = 5)
  translate_options = dict(task='translate', **options)
  result = model.transcribe(audio_file,**translate_options)
  return result

# %%
result = translate(audio_file)
print(result['text'])
# Out:
#  and that's how you manage to create your world. And this is what I did through the language of motivation. And of course, to make sure I did it perfectly well, first of all, I consulted with the experts, the children. I missed it.
